# %% [markdown]
# # <center> Crocodile or Alligator Classification using Support Vector Machine </center>
# #### *<center>By Peter Kayode</center>*

# %% [markdown]
# ### Import neccessary Libraries

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
x, y = make_blobs(n_samples = 40, centers = 2, random_state = 20)

# %% [markdown]
# ### Train the Model

# %%
clf = svm.SVC(kernel = "linear", C = 1)
clf.fit(x, y)
# Out:
# SVC(C=1, kernel='linear')

# %%
# Display the data in graph form

plt.scatter(x[:, 0], x[:, 1], c= y, s = 30, cmap = plt.cm.Paired)
plt.show()

# %% [markdown]
# ### Predicting using the model

# %%
# Using to predict unknown data

newData = [[3, 4], [5, 6]]
print(clf.predict(newData))
# Out:
# [0 1]

# %%
# fit the model, 

clf = svm.SVC(kernel = "linear", C = 1000)
clf.fit(x, y)
plt.scatter(x[:, 0], x[:, 1], c = y, s = 30, cmap = plt.cm.Paired)
# plt.show()


# Plot the decision function
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# Create grid to evaluate the model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(xlim[0], ylim[1], 30)
yy, xx = np.meshgrid(yy, xx)
xy = np.vstack([xx.ravel(), yy.ravel()]).T
z = clf.decision_function(xy).reshape(xx.shape)

# Plot decision boundary and margins
ax.contour(xx, yy, z, colors = "k", levels = [-1, 0, 1], alpha = 0.5, linestyle = ["--", "-", "--"])

# Plot support vectors
ax.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s = 100, linewidth = 1, facecolors = "none")
plt.xlabel("Width of the snout")
plt.ylabel("Size of the body")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_26408\2236897039.py:22: UserWarning: The following kwargs were not used by contour: 'linestyle'
#   ax.contour(xx, yy, z, colors = "k", levels = [-1, 0, 1], alpha = 0.5, linestyle = ["--", "-", "--"])
